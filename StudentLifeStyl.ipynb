# %% [markdown]
# DATASET --> https://www.kaggle.com/datasets/steve1215rogg/student-lifestyle-dataset/data

# %% [markdown]
# ## 📂 Dataset Overview
#
# - **File Name:** `Daily_Lifestyle_and_Academic_Performance.csv`
# - **File Format:** CSV
# - **File Size:** ~150 KB
# - **Number of Records (Rows):** 2,000
# - **Number of Columns:** 8
#
# ### 📊 Column Details
# 1. **Student ID** – Identificador único del estudiante
# 2. **Study Hours** – Horas de estudio diarias
# 3. **Extracurricular Hours** – Horas dedicadas a actividades extracurriculares
# 4. **Sleep Hours** – Horas de sueño diarias
# 5. **Social Hours** – Horas dedicadas a la vida social
# 6. **Physical Activity Hours** – Horas de actividad física
# 7. **Stress Level** – Nivel de estrés del estudiante
# 8. **CGPA** – Promedio acumulado (rendimiento académico)

# %% [markdown]
# ## IMPORTS

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans

# %% [markdown]
# ## CSV

# %%
# Carga del csv
studentData = pd.read_csv("dataset/student_lifestyle_dataset.csv")

# %%
studentData.head()
# Out:
#    Student_ID  Study_Hours_Per_Day  Extracurricular_Hours_Per_Day  \
# 0           1                  6.9                            3.8
# 1           2                  5.3                            3.5
# 2           3                  5.1                            3.9
# 3           4                  6.5                            2.1
# 4           5                  8.1                            0.6
#
#    Sleep_Hours_Per_Day  Social_Hours_Per_Day  Physical_Activity_Hours_Per_Day  \
# 0                  8.7                   2.8                              1.8
# 1                  8.0                   4.2                              3.0
# 2                  9.2                   1.2                              4.6
# 3                  7.2                   1.7                              6.5
# 4                  6.5                   2.2                              6.6
#
#     GPA Stress_Level
# 0  2.99     Moderate
# 1  2.75          Low
# 2  2.67          Low
# ...

# %%
studentData.shape
# Out:
# (2000, 8)

# %% [markdown]
# ## 1 --> LIMPIEZA

# %%
# Porcentaje de nulos
studentData.isnull().sum()/ len(studentData) * 100
# Out:
# Student_ID                         0.0
# Study_Hours_Per_Day                0.0
# Extracurricular_Hours_Per_Day      0.0
# Sleep_Hours_Per_Day                0.0
# Social_Hours_Per_Day               0.0
# Physical_Activity_Hours_Per_Day    0.0
# GPA                                0.0
# Stress_Level                       0.0
# dtype: float64

# %% [markdown]
# ## 2 --> ANALISIS EXPLORATORIO

# %%
df_numerico = studentData.select_dtypes(include=["float64", "int64"])

matriz_correlacion = df_numerico.corr()

plt.figure(figsize=(16, 8)) 
sns.heatmap(matriz_correlacion, annot=True, cmap="coolwarm", fmt=".2f", linewidths=0.5)
plt.title("Mapa de correlación entre variables numéricas")
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
# Selecciona solo las columnas numéricas
columnas_numericas = studentData.select_dtypes(include=['float64', 'int64']).columns

# Genera un histograma por cada columna
for col in columnas_numericas:
    plt.figure(figsize=(15, 5))
    sns.histplot(trackData[col], kde=True, bins=30, color='dodgerblue')
    plt.title(f'Distribución de {col}', fontsize=16)
    plt.xlabel(col, fontsize=12)
    plt.ylabel('Frecuencia', fontsize=12)
    plt.grid(True)
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 7
#       5 for col in columnas_numericas:
#       6     plt.figure(figsize=(15, 5))
# ----> 7     sns.histplot(trackData[col], kde=True, bins=30, color='dodgerblue')
#       8     plt.title(f'Distribución de {col}', fontsize=16)
#       9     plt.xlabel(col, fontsize=12)
#
# NameError: name 'trackData' is not defined

# %% [markdown]
# ## 3 --> EXPORT TO CSV

# %%
studentData.to_csv('dataset/studentData_resumen.csv', index=False)
